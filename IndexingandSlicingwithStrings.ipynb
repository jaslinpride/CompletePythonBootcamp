# %%
mystring = "Hello World"

# %%
mystring
# Out:
# 'Hello World'

# %% [markdown]
# To grab a single character (Indexing) in the string

# %%
mystring[0]
# Out:
# 'H'

# %%
mystring[8]
# Out:
# 'r'

# %%
mystring[9]
# Out:
# 'l'

# %%
mystring
# Out:
# 'Hello World'

# %% [markdown]
# Reverse Indexing

# %%
mystring[-2]
# Out:
# 'l'

# %%
mystring[-3]
# Out:
# 'r'

# %% [markdown]
# To discover the last letter of the string just use "-1"

# %%
mystring[-1]
# Out:
# 'd'

# %% [markdown]
# Slicing

# %%
mystring = 'abcdefghijk'

# %%
mystring
# Out:
# 'abcdefghijk'

# %% [markdown]
# To grab a subsection of the string that started at a particular index and goes all the way to the end

# %%
mystring[2]
# Out:
# 'c'

# %%
mystring[2:]
# Out:
# 'cdefghijk'

# %% [markdown]
# To grab everything up to a particular index

# %%
mystring[:3]
# Out:
# 'abc'

# %% [markdown]
# Grabbing a subsection of a string that is in the middle

# %%
mystring[3:6]
# Out:
# 'def'

# %%
mystring[1:3]
# Out:
# 'bc'

# %% [markdown]
# Step Size: Beginning to end of string
# Colon Notation

# %%
mystring[::]
# Out:
# 'abcdefghijk'

# %%
mystring[::1]
# Out:
# 'abcdefghijk'

# %%
mystring[::2]
# Out:
# 'acegik'

# %%
mystring[::3]
# Out:
# 'adgj'

# %% [markdown]
# (Start) starting at index 2, (Stop) go up to but not including index 7, (Step) step size of 2

# %%
mystring[2:7:2]
# Out:
# 'ceg'

# %% [markdown]
# Trick to reverse a string

# %%
mystring[::-1]
# Out:
# 'kjihgfedcba'

# %%
"Hello World" [-3]
# Out:
# 'r'
