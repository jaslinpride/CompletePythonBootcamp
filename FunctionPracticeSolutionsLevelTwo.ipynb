# %% [markdown]
# LEVEL 2 PROBLEMS

# %% [markdown]
# FIND 33: Given a list of ints, return True if the array contains a 3 next to a 3 somewhere.

# %%
def has_33(nums):

  for i in range(0,len(nums)-1):
    if nums[i] == 3 and nums[i+1] == 3:
      return True

  return False

# %%
has_33([1, 3, 3])
# Out:
# True

# %%
has_33([1, 3, 1, 3])
# Out:
# False

# %%
has_33([3, 1, 3])
# Out:
# False

# %% [markdown]
# Alternative

# %%
def has_33(nums):

  for i in range(0,len(nums)-1):
    if nums[i:i+2] == [3,3]:
      return True

  return False

# %%
has_33([1, 3, 3])
# Out:
# True

# %%
has_33([1, 3, 1, 3])
# Out:
# False

# %%
has_33([3, 1, 3])
# Out:
# False

# %% [markdown]
# LAUGHTER: Write a function that counts the number of times a given pattern appears in a string, including overlap

# %% [markdown]
# PAPER DOLL: Given a string, return a string where for every character in the original there are three characters

# %%
def paper_doll(text):
  result = ''

  for char in text:
    result += char*3

  return result

# %%
paper_doll('Hello')
# Out:
# 'HHHeeellllllooo'

# %%
paper_doll('Mississippi')
# Out:
# 'MMMiiissssssiiissssssiiippppppiii'

# %% [markdown]
# Or you can do addition instead of multiplication

# %%
def paper_doll(text):
  result = ''

  for char in text:
    result += char+char+char

  return result

# %%
paper_doll('Hello')
# Out:
# 'HHHeeellllllooo'

# %%
paper_doll('Mississippi')
# Out:
# 'MMMiiissssssiiissssssiiippppppiii'

# %% [markdown]
# BLACKJACK: Given three integers between 1 and 11, if their sum is less than or equal to 21, return their sum. If their sum exceeds 21 and there is an eleven, reduce the total sum by 10. Finally, if the sum (even after adjustment) exceeds 21, return ‘BUST’.

# %%
def blackjack(a,b,c):
  if sum([a,b,c]) <= 21:
    return sum([a,b,c])
  elif 11 in [a,b,c] and sum ([a,b,c]) <= 31:
    return sum ([a,b,c]) - 10
  else:
      return "BUST"

# %%
blackjack(5,6,7)
# Out:
# 18

# %%
blackjack(9,9,9)
# Out:
# 'BUST'

# %%
blackjack(9,9,11)
# Out:
# 19

# %% [markdown]
# Replacing "31" with "21"

# %%
def blackjack(a,b,c):
  if sum([a,b,c]) <= 21:
    return sum([a,b,c])
  elif 11 in [a,b,c] and sum ([a,b,c]) - 10 <= 21:
    return sum ([a,b,c]) - 10
  else:
      return "BUST"

# %%
blackjack(5,6,7)
# Out:
# 18

# %%
blackjack(9,9,9)
# Out:
# 'BUST'

# %%
blackjack(9,9,11)
# Out:
# 19

# %% [markdown]
# SUMMER OF ‘69: Return the sum of the numbers in the array, except ignore sections of numbers starting with a 6 and extended to the next 9 (every 6 will be followed by at least one 9). Return 0 for no numbers.

# %%
def summer_69(arr):

  total = 0
  add = True

  for num in arr:
      while add:
            if num != 6:
              total += num
              break
            else:
              add = False
      while not add:
        if num != 9:
          break
        else:
          add = True
          break
  return total

# %%
summer_69([1, 3, 5])
# Out:
# 9

# %%
summer_69([4, 5, 6, 7, 8, 9])
# Out:
# 9

# %%
summer_69([2, 1, 6, 9, 11])
# Out:
# 14
