# %%
'hello'
# Out:
# 'hello'

# %%
"world"
# Out:
# 'world'

# %% [markdown]
# The white spaces also count as characters inside of a string.

# %%
'this is also a string'
# Out:
# 'this is also a string'

# %% [markdown]
# Can mix single quotes and double quotes

# %%
" I'm going on a run "
# Out:
# " I'm going on a run "

# %%
print("hello")
# Out:
# hello

# %%
"hello world one"
"hello world two"
# Out:
# 'hello world two'

# %%
print("hello world one")
print("hello world two")
# Out:
# hello world one
# hello world two

# %%
print('hello world')
# Out:
# hello world

# %%
print('hello \n world')
# Out:
# hello
#  world

# %% [markdown]
# To perfectly align hello and world

# %%
print('hello \nworld')
# Out:
# hello
# world

# %% [markdown]
# Tab

# %%
print('hello \tworld')
# Out:
# hello 	world

# %% [markdown]
# Length Function

# %%
len('hello')
# Out:
# 5

# %% [markdown]
# Spaces count in the len function

# %%
len('I am')
# Out:
# 4
