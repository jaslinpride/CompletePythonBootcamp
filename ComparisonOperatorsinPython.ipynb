# %% [markdown]
# Equality

# %%
2 == 2
# Out:
# True

# %%
2 == 1
# Out:
# False

# %%
'hello' == 'bye'
# Out:
# False

# %% [markdown]
# Capitalization counts

# %%
'Bye' == 'bye'
# Out:
# False

# %% [markdown]
# Python considers types (string versus integer)

# %%
'2' == 2
# Out:
# False

# %% [markdown]
# Floating points hold the same value as integers

# %%
2.0 == 2
# Out:
# True

# %% [markdown]
# Inequality

# %%
3 != 3
# Out:
# False

# %%
4 != 5
# Out:
# True

# %% [markdown]
# Greater than

# %%
2 > 1
# Out:
# True

# %%
1 > 2
# Out:
# False

# %%
1 < 2
# Out:
# True

# %%
2 < 5
# Out:
# True

# %% [markdown]
# Greater Than or Equal To

# %%
2 >= 2
# Out:
# True

# %% [markdown]
# Less Than or Equal To

# %%
4 <= 1
# Out:
# False
