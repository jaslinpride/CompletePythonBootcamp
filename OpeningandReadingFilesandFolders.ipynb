# %%
pwd
# Out:
# '/content'

# %%
f = open('practice.txt','w+')
f.write('This is a test string')
f.close()

# %% [markdown]
# How to Use the OS Module

# %%
import os

# %% [markdown]
# Report Back the Current Working Directory

# %%
os.getcwd()
# Out:
# '/content'

# %% [markdown]
# To List Items in a Directory

# %%
os.listdir()
# Out:
# ['.config', 'practice.txt', 'sample_data']

# %% [markdown]
# List Items in Another Directory

# %%
os.listdir(‘C:\\Users’)
# Out:
#   File "/tmp/ipykernel_3907/1552890636.py", line 1
#     os.listdir(‘C:\\Users’)
#                ^
# SyntaxError: invalid character '‘' (U+2018)

# %% [markdown]
# How to Move Files

# %%
 import shutil

# %%
shutil.move('practice.txt', '/content')
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /tmp/ipykernel_3907/1568863296.py in <cell line: 0>()
# ----> 1 shutil.move('practice.txt', '/content')
#
# /usr/lib/python3.12/shutil.py in move(src, dst, copy_function)
#     843
#     844         if os.path.exists(real_dst):
# --> 845             raise Error("Destination path '%s' already exists" % real_dst)
#     846     try:
#     847         os.rename(src, real_dst)
#
# Error: Destination path '/content/practice.txt' already exists

# %%
os.listdir('/content')
# Out:
# ['.config', 'practice.txt', 'sample_data']

# %%
import send2trash

# %% [markdown]
# Checking Directory

# %%
os.listdir()
# Out:
# ['.config', 'practice.txt', 'sample_data']

# %% [markdown]
# Moving “practice.txt” to Current Working Directory

# %%
shutil.move('/content', os.getcwd())

# %% [markdown]
# Send “practice.txt” to Trash

# %%
send2trash.send2trash('practice.txt')

# %% [markdown]
# os.walk

# %%
os.getcwd()
# Out:
# '/content'

# %%
file_path = '/content'

# %%
for folder, sub_folders,files in os.walk(file_path):

  print(f"Currently looking at {folder}")
  print('\n')
  print('The subfolders are: ')
  for sub_fold in sub_folders:
    print(f"\t Subfolder: {sub_fold}")

  print('\n')
  print("the files are: ")
  for f in files:
    print(f"\t File: {f}")
  print('\n')
# Out:
# Currently looking at /content
#
#
# The subfolders are:
# 	 Subfolder: .config
# 	 Subfolder: sample_data
#
#
# the files are:
#
#
# Currently looking at /content/.config
#
#
# The subfolders are:
# 	 Subfolder: configurations
# 	 Subfolder: logs
#
#
# the files are:
# 	 File: active_config
# 	 File: .last_update_check.json
# 	 File: .last_survey_prompt.yaml
# 	 File: gce
# 	 File: .last_opt_in_prompt.yaml
# 	 File: config_sentinel
# 	 File: default_configs.db
# 	 File: hidden_gcloud_config_universe_descriptor_data_cache_configs.db
#
#
# Currently looking at /content/.config/configurations
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: config_default
#
#
# Currently looking at /content/.config/logs
#
#
# The subfolders are:
# 	 Subfolder: 2026.04.16
#
#
# the files are:
#
#
# Currently looking at /content/.config/logs/2026.04.16
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: 13.28.21.827521.log
# 	 File: 13.27.28.140888.log
# 	 File: 13.27.53.684484.log
# ...
