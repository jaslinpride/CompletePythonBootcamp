# %%
t = (1,2,3)

# %%
mylist = [1,2,3]

# %%
type(t)
# Out:
# tuple

# %%
type(mylist)
# Out:
# list

# %% [markdown]
# Checking the Length

# %%
len(t)
# Out:
# 3

# %%
t
# Out:
# (1, 2, 3)

# %% [markdown]
# Can Mix Object Types

# %%
t = ('one',2)

# %% [markdown]
# Can use slicing and indexing

# %%
t[0]
# Out:
# 'one'

# %%
t[-1]
# Out:
# 2

# %% [markdown]
# Index Method

# %%
t = ('a','a','b')

# %% [markdown]
# Count how many times a shows in the tuple

# %%
t.count('a')
# Out:
# 2

# %% [markdown]
# Return the first time the letter a shows in the tuple

# %%
t.index('a')
# Out:
# 0

# %%
t.index('b')
# Out:
# 2

# %% [markdown]
# Immutability

# %%
mylist
# Out:
# [1, 2, 3]

# %%
mylist[0] = 'NEW'

# %%
mylist
# Out:
# ['NEW', 2, 3]

# %%
t[0] = 'NEW'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_16963/2140988817.py in <cell line: 0>()
# ----> 1 t[0] = 'NEW'
#
# TypeError: 'tuple' object does not support item assignment
