# %% [markdown]
# Condition that executes when doing two comparisons

# %%
1 < 2
# Out:
# True

# %%
2 < 3
# Out:
# True

# %%
1 < 2 < 3
# Out:
# True

# %%
1 < 2 > 3
# Out:
# False

# %% [markdown]
# Alternatively, create a Logical Operator using "and"

# %%
1 < 2 and 2 > 3
# Out:
# False

# %%
1 < 2 and 2 < 3
# Out:
# True

# %%
'h' == 'h' and 2 == 2
# Out:
# True

# %% [markdown]
# Create a Logical Operator using "or"

# %%
1 == 1 or 2 == 2
# Out:
# True

# %% [markdown]
# "or" needs only one to be true

# %%
100 == 1 or 2 == 2
# Out:
# True

# %% [markdown]
# Create a Logical Operator using "Not"

# %%
1 == 1
# Out:
# True

# %%
not(1 == 1)
# Out:
# False

# %% [markdown]
# With or without parentheses

# %%
not 1 == 1
# Out:
# False

# %%
400 > 5000
# Out:
# False

# %%
not 400 > 5000
# Out:
# True
