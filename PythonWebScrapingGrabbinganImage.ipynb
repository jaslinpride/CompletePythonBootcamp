# %% [markdown]
# Wikipedia: Deep Blue (chess computer)

# %%
import requests

# %%
result = requests.get("https://en.wikipedia.org/wiki/Deep_Blue_(chess_computer")

# %%
import bs4

# %%
res = requests.get("https://en.wikipedia.org/wiki/Deep_Blue_(chess_computer")

# %% [markdown]
# Make a Soup

# %%
soup = bs4.BeautifulSoup(res.text,'lxml')

# %%
soup
# Out:
# <html><body>Please set a user-agent and respect our robot policy https://w.wiki/4wJS. See also https://phabricator.wikimedia.org/T400119.
# </body></html>

# %%
soup.select('img')
# Out:
# []

# %%
soup.select('.thumbimage')
# Out:
# []

# %% [markdown]
# Checking Image Information and Downloading it

# %%
computer = soup.select('thumbimage')[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_16314/2603300781.py in <cell line: 0>()
# ----> 1 computer = soup.select('thumbimage')[0]
#
# IndexError: list index out of range

# %%
computer
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_16314/3592614864.py in <cell line: 0>()
# ----> 1 computer
#
# NameError: name 'computer' is not defined

# %%
type(computer)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_16314/1529183550.py in <cell line: 0>()
# ----> 1 type(computer)
#
# NameError: name 'computer' is not defined

# %%
computer['class']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_16314/2791239662.py in <cell line: 0>()
# ----> 1 computer['class']
#
# NameError: name 'computer' is not defined

# %%
computer['src']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_16314/434246564.py in <cell line: 0>()
# ----> 1 computer['src']
#
# NameError: name 'computer' is not defined

# %% [markdown]
# Treat as Dictionary for Asset or Parameter Call

# %%
<img
src="//upload.wikimedia.org/wikipedia/commons/thumb/b/be/Deep_Blue.jpg/220px-Deep_Blue.jpg"
# Out:
#   File "/tmp/ipykernel_16314/4223540878.py", line 1
#     <img
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# Downloading to Avoid Depending on Website

# %%
image_link = requests.get('https://upload.wikimedia.org/wikipedia/commons/thumb/b/be/Deep_Blue.jpg/220px-Deep_Blue.jpg')

# %%
image_link.content
# Out:
# b'Please set a user-agent and respect our robot policy https://w.wiki/4wJS. See also https://phabricator.wikimedia.org/T400119.\n'

# %% [markdown]
# Save Image on Computer in the form of an Image

# %%
f = open('my_computer_image.jpg','wb')

# %%
f.write(image_link.content)
# Out:
# 126

# %%
f.close()
