# %%
import imaplib

# %%
M = imaplib.IMAP4_SSL('imap.gmail.com')

# %%
import getpass

# %%
email = getpass.getpass("Email: ")
password = getpass.getpass('Password: ')
# Out:
# Email: ··········
# Password: ··········

# %% [markdown]
# Connect

# %%
M.login(email,password)
# Out:
# ('OK', [b'terianajaslinpride@gmail.com authenticated (Success)'])

# %%
M.list()
# Out:
# ('OK',
#  [b'(\\HasNoChildren) "/" "INBOX"',
#   b'(\\HasNoChildren) "/" "LSAT Study"',
#   b'(\\HasChildren \\Noselect) "/" "[Gmail]"',
#   b'(\\All \\HasNoChildren) "/" "[Gmail]/All Mail"',
#   b'(\\Drafts \\HasNoChildren) "/" "[Gmail]/Drafts"',
#   b'(\\HasNoChildren \\Important) "/" "[Gmail]/Important"',
#   b'(\\HasNoChildren \\Sent) "/" "[Gmail]/Sent Mail"',
#   b'(\\HasNoChildren \\Junk) "/" "[Gmail]/Spam"',
#   b'(\\Flagged \\HasNoChildren) "/" "[Gmail]/Starred"',
#   b'(\\HasNoChildren \\Trash) "/" "[Gmail]/Trash"'])

# %% [markdown]
# Select Inbox

# %%
M.select('inbox')
# Out:
# ('OK', [b'1522'])

# %% [markdown]
# Search for Mail Using Specialized Syntax for IMAP

# %%
typ, date = M.search(None,'SUBJECT "NEW TEST PYTHON"')

# %%
typ
# Out:
# 'OK'

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4369/391604064.py in <cell line: 0>()
# ----> 1 data
#
# NameError: name 'data' is not defined

# %% [markdown]
# Fetch the E-Mail Itself

# %%
email_id = data[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4369/1150742615.py in <cell line: 0>()
# ----> 1 email_id = data[0]
#
# NameError: name 'data' is not defined

# %%
result , email_data = M.fetch(email_id,'(RFC822)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4369/4204640918.py in <cell line: 0>()
# ----> 1 result , email_data = M.fetch(email_id,'(RFC822)')
#
# NameError: name 'email_id' is not defined

# %%
email_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4369/4241918220.py in <cell line: 0>()
# ----> 1 email_data
#
# NameError: name 'email_data' is not defined

# %% [markdown]
# Grab the Message from the E-Mail Data Tuple using Indexing

# %%
raw_email = email_data[0][1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4369/611121352.py in <cell line: 0>()
# ----> 1 raw_email = email_data[0][1]
#
# NameError: name 'email_data' is not defined

# %% [markdown]
# Decoded due to “@” Symbol

# %%
raw_email_string = raw_email.decode('utf-8')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4369/1485262091.py in <cell line: 0>()
# ----> 1 raw_email_string = raw_email.decode('utf-8')
#
# NameError: name 'raw_email' is not defined

# %% [markdown]
# Use Built-in E-Mail Library to Parse the String

# %%
import email

# %%
email_message = email.message_from_string(raw_email_string)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4369/2643633211.py in <cell line: 0>()
# ----> 1 email_message = email.message_from_string(raw_email_string)
#
# NameError: name 'raw_email_string' is not defined

# %%
email_message
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4369/3077221813.py in <cell line: 0>()
# ----> 1 email_message
#
# NameError: name 'email_message' is not defined

# %%
for part in email_message.walk():

  if part.get_content_type() == 'text/plain':
    body = part.get_payload(decode=True)
    print(body)
