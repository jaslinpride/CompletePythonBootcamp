# %% [markdown]
# Error and Example on Using Print Statement

# %%
x = [1,2,3]
y = 2
z = 3

result = y + z
result2 = x + y
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_9099/3251481453.py in <cell line: 0>()
#       4
#       5 result = y + z
# ----> 6 result2 = x + y
#
# TypeError: can only concatenate list (not "int") to list

# %% [markdown]
# More Complicated Error
#
# - Try printing out individual results

# %%
x = [1,2,3]
y = 2
z = 3

result = y + z
print(result)
result2 = x + y
print(y)
print(result2)
# Out:
# 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_9099/1935662721.py in <cell line: 0>()
#       5 result = y + z
#       6 print(result)
# ----> 7 result2 = x + y
#       8 print(y)
#       9 print(result2)
#
# TypeError: can only concatenate list (not "int") to list

# %% [markdown]
# Using the Python Debugger to set a Trace
#
# Trace: pause operations mid script and then allow you to play with variables to understand what is going on to avoid the need to add print() functions to figure out individual results

# %%
import pdb

# %%
x = [1,2,3]
y = 2
z = 3

result_one = y + z

pdb.set_trace()

result_two = y + x
# Out:
# --Return--
# None
# > /tmp/ipykernel_9099/1912475531.py(7)<cell line: 0>()
#       5 result_one = y + z
#       6
# ----> 7 pdb.set_trace()
#       8
#       9 result_two = y + x
#
# ipdb> x
# [1, 2, 3]
# ipdb> result_one
# 5
# ipdb> y
# 2
# ipdb> x
# [1, 2, 3]
# ipdb> q
