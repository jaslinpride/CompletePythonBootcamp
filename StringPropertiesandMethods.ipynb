# %% [markdown]
# Immutability

# %%
name = "Sam"

# %% [markdown]
# Change name from Sam to Pam. Strings are immutable; therefore, you cannot do name[0] = 'P'

# %%
# name[0] = 'P'

# %% [markdown]
# Can create a new string with concatenation (merging two strings together)

# %%
last_letters = name[1:]

# %%
last_letters
# Out:
# 'am'

# %%
'P' + last_letters
# Out:
# 'Pam'

# %%
x = 'Hello World'

# %%
x + " it is beautiful outside!"
# Out:
# 'Hello World it is beautiful outside!'

# %%
x = x + " it is beautiful outside!"

# %%
x
# Out:
# 'Hello World it is beautiful outside!'

# %% [markdown]
# If you accidentally run it twice

# %%
x = x + " it is beautiful outside"

# %%
x
# Out:
# 'Hello World it is beautiful outside! it is beautiful outside it is beautiful outside'

# %% [markdown]
# Multiple String Concatenations at Once

# %%
letter = 'z'

# %%
letter * 10
# Out:
# 'zzzzzzzzzz'

# %% [markdown]
# When performing string multiplication you will get errors if you try to concatenate a number with a string

# %%
2 + 3
# Out:
# 5

# %%
'2' + '3'
# Out:
# '23'

# %% [markdown]
# Objects in Python usually have built-in methods. These methods are functions that are inside the object.

# %%
x = 'Hello World'

# %%
x.upper()
# Out:
# 'HELLO WORLD'

# %%
x
# Out:
# 'Hello World'

# %% [markdown]
# To ask python what a function is without executing, type the function without parentheses.

# %%
x.upper
# Out:
# <function str.upper()>

# %% [markdown]
# Lowercase

# %%
x.lower()
# Out:
# 'hello world'

# %% [markdown]
# Split Method

# %%
x.split()
# Out:
# ['Hello', 'World']

# %% [markdown]
# Split by White Space

# %%
x = 'Hi this is a string'

# %%
x.split()
# Out:
# ['Hi', 'this', 'is', 'a', 'string']

# %% [markdown]
# Split based on letter "i"

# %%
x.split('i')
# Out:
# ['H', ' th', 's ', 's a str', 'ng']
