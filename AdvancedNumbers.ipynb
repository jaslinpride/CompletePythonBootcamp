# %% [markdown]
# Hexadecimal

# %%
hex(12)
# Out:
# '0xc'

# %%
hex(512)
# Out:
# '0x200'

# %% [markdown]
# Binary

# %%
bin(1234)
# Out:
# '0b10011010010'

# %%
bin(128)
# Out:
# '0b10000000'

# %%
bin(512)
# Out:
# '0b1000000000'

# %% [markdown]
# pow()

# %%
2**4
# Out:
# 16

# %%
pow(2,4)
# Out:
# 16

# %%
pow(2,4,3)
# Out:
# 1

# %% [markdown]
# Absolute Value

# %%
abs(-3)
# Out:
# 3

# %%
abs(2)
# Out:
# 2

# %% [markdown]
# Round

# %%
round(3.1)
# Out:
# 3

# %%
round(3)
# Out:
# 3

# %%
round(3.9)
# Out:
# 4

# %% [markdown]
# Can specify the number of digits desired after a decimal point

# %%
round(3.141592,2)
# Out:
# 3.14
