# %% [markdown]
# Add Method

# %%
s = set()

# %%
s.add(1)

# %%
s.add(2)

# %%
s
# Out:
# {1, 2}

# %% [markdown]
# Will not take duplicate elements and only present them once.

# %%
s.add(2)

# %%
s
# Out:
# {1, 2}

# %% [markdown]
# Clear Method

# %%
s.clear()

# %%
s
# Out:
# set()

# %% [markdown]
# Copy

# %%
s = {1,2,3}

# %%
sc = s.copy()

# %%
sc
# Out:
# {1, 2, 3}

# %% [markdown]
# Adding to a Copied Set

# %%
s.add(4)

# %%
s
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# Difference Method

# %%
s.difference(sc)
# Out:
# {4}

# %% [markdown]
# Difference Update Method

# %%
s1 = {1,2,3}

# %%
s2 = {1,4,5}

# %%
s1.difference_update(s2)

# %%
s1
# Out:
# {2, 3}

# %% [markdown]
# Discard Method

# %%
s.discard(2)

# %%
s
# Out:
# {1, 3, 4}

# %% [markdown]
# Intersection Method

# %%
s1 = {1,2,3}

# %%
s2 = {1,2,4}

# %%
s1.intersection(s2)
# Out:
# {1, 2}

# %% [markdown]
# Intersection Update Method

# %%
s1
# Out:
# {1, 2, 3}

# %%
s1.intersection_update(s2)

# %%
s1
# Out:
# {1, 2}

# %% [markdown]
# isdisjoint Method

# %%
s1 - {1,2}
s2 = {1,2,4}
s3 = {5}

# %%
s1.isdisjoint(s2)
# Out:
# False

# %%
s1.isdisjoint(s3)
# Out:
# True

# %% [markdown]
# issubset Method

# %%
s1
# Out:
# {1, 2}

# %%
s2
# Out:
# {1, 2, 4}

# %%
s1.issubset(s2)
# Out:
# True

# %% [markdown]
# issuperset Method

# %%
s2.issuperset(s1)
# Out:
# True

# %% [markdown]
# Symmetric Difference Method

# %%
s1.symmetric_difference(s2)
# Out:
# {4}

# %% [markdown]
# Union Method

# %%
s1.union(s2)
# Out:
# {1, 2, 4}

# %% [markdown]
# Update Method

# %%
s1.update(s2)

# %%
s1
# Out:
# {1, 2, 4}
