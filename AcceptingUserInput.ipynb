# %%
row1 = [' ',' ',' ']
row2 = [' ',' ',' ']
row3 = [' ',' ',' ']

# %%
display(row1,row2,row3)
# Out:
# [' ', ' ', ' ']
# [' ', ' ', ' ']
# [' ', ' ', ' ']

# %%
row2[1] = 'X'

# %%
display(row1,row2,row3)
# Out:
# [' ', ' ', ' ']
# [' ', 'X', ' ']
# [' ', ' ', ' ']

# %% [markdown]
# Learned about the .input() function in the “Useful Operators” lecture

# %%
input("Please enter a value: ")
# Out:
# Please enter a value: 2
# '2'

# %% [markdown]
# Save the output as a result

# %%
result = input("Please enter a value: ")
# Out:
# Please enter a value: 2

# %%
result
# Out:
# '2'

# %% [markdown]
# If you want it to return a different type, e.g., a floating point or integer, convert it. Use built-in casting functions.

# %%
result = input("Enter Value: ")
# Out:
# Enter Value: 2

# %%
result_int = int(result)

# %%
type(result)
# Out:
# str

# %%
type(result_int)
# Out:
# int

# %%
type(2.3)
# Out:
# float

# %%
float('3.14')
# Out:
# 3.14

# %% [markdown]
# Input function will always return a string, meaning you may need to convert it if you actually need a specific data type within your function

# %%
position_index = input("Choose an index position:")
# Out:
# Choose an index position:2

# %% [markdown]
# Recall, you have “row1,” “row2,” “row3”

# %%
row1
# Out:
# [' ', ' ', ' ']

# %% [markdown]
# When using user input, Python will automatically pass it in as a string. In order to use it in your program you need to convert it into a different data type, e.g., integer or a floating point number.

# %%
position_index = input("Choose an index position:")
# Out:
# Choose an index position:2

# %%
type(position_index)
# Out:
# str

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2107/1148997657.py in <cell line: 0>()
# ----> 1 row2[position_index]
#
# TypeError: list indices must be integers or slices, not str

# %% [markdown]
# The input function itself can be confusing because it awaits a user interaction, which means if you accidentally run it twice your Python program or script may get stuck waiting for a reply that does not actually come.

# %%
result = input("Enter a number: ")
# Out:
# Enter a number: 2

# %% [markdown]
# You have to go back up and “Enter a number: ” so the rest of the cells can actually execute.

# %%
2+2
# Out:
# 4

# %% [markdown]
# Sometimes, you can accidentally run the cell twice

# %%
input("Enter Number: ")
