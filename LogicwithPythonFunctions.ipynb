# %% [markdown]
# Mod Operator: returns the remainder after a division

# %%
2 % 2
# Out:
# 0

# %%
3 % 2
# Out:
# 1

# %%
41 % 40
# Out:
# 1

# %% [markdown]
# If a number is even

# %%
20 % 2
# Out:
# 0

# %%
20 % 2 == 0
# Out:
# True

# %% [markdown]
# If a number is odd

# %%
21 % 2 == 0
# Out:
# False

# %% [markdown]
# Constructed into a function

# %%
def even_check(number):
  result = number % 2 == 0
  return result

# %%
even_check(20)
# Out:
# True

# %%
even_check(21)
# Out:
# False

# %% [markdown]
# Or you can do

# %%
def even_check(number):
  return number % 2 == 0

# %%
even_check(20)
# Out:
# True

# %%
even_check(21)
# Out:
# False

# %% [markdown]
# Checking even or odd inside of a list

# %%
# RETURN TRUE IF ANY NUMBER IS EVEN INSIDE A LIST

# %%
def check_even_list(num_list):

  for number in num_list:
    if number % 2 == 0:
      return True
    else:
      pass

# %%
check_even_list([1,3,5])

# %%
check_even_list([2,4,5])
# Out:
# True

# %%
check_even_list([2,1,1,1])
# Out:
# True

# %%
check_even_list([1,1,1,2])
# Out:
# True

# %% [markdown]
# To return False for odd

# %%
def check_even_list(num_list):

  for number in num_list:
    if number % 2 == 0:
      return True
    else:
      pass

  return False

# %%
check_even_list([1,3,5])
# Out:
# False

# %% [markdown]
# Return all the even numbers in the list

# %%
def check_even_list(num_list):

  # placeholder variables
  even_numbers = []

  for number in num_list:
    if number % 2 == 0:
      even_numbers.append(number)
    else:
      pass

  return even_numbers

# %%
check_even_list([1,2,3,4,5])
# Out:
# [2, 4]

# %%
check_even_list([1,3,5])
# Out:
# []
