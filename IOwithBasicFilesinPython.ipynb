# %% [markdown]
# Magic functionality to write a text file

# %%
# %%writefile myfile.txt
# Hello this is a text file
# this is the second line
# this is the third line
# Out:
# Writing myfile.txt

# %% [markdown]
# Sometimes you either write the wrong name of the file or save the file in the wrong directory

# %%
myfile = open('myfile.txt')

# %% [markdown]
# Asking for a file that is not there

# %% [markdown]
# Print Working Directory for Notebook location. Text files should be saved in the same location.

# %%
pwd
# Out:
# '/content'

# %%
myfile = open('myfile.txt')

# %%
myfile.read()
# Out:
# 'Hello this is a text file\nthis is the second line\nthis is the third line\n'

# %% [markdown]
# You can imagine a cursor at the beginning of the file and when you read it the cursor goes to the end of the file. When you re-seek the file you need to take the cursor back to the beginning of the file to read it again.

# %%
myfile.read()
# Out:
# ''

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# 'Hello this is a text file\nthis is the second line\nthis is the third line\n'

# %%
contents = myfile.read()

# %%
contents
# Out:
# ''

# %% [markdown]
# Read Lines Method

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.readlines()
# Out:
# ['Hello this is a text file\n',
#  'this is the second line\n',
#  'this is the third line\n']

# %% [markdown]
# File Locations
#
# If you want to open files at another location on your computer, simply pass in the entire file path.
#
# For Windows you need to use double \ so python does not threat the second \ as an escape character, a file path is in the form:
#
# myfile = open("C:\\Users\\UserName\\Folder\\test.txt")
#
# For MacOS and Linux you use slashes in the opposite direction:
#
# myfile = open("/Users/YourUserName/Folder/myfile.txt")

# %%
pwd
# Out:
# '/content'

# %% [markdown]
# Best Practices
# To close file after Opening

# %%
myfile.close()

# %%
with open('myfile.txt') as my_new_file:
  contents = my_new_file.read()

# %%
contents
# Out:
# 'Hello this is a text file\nthis is the second line\nthis is the third line\n'

# %% [markdown]
# Write to Files

# %%
with open('myfile.txt',mode='r') as myfile:
  contents = myfile.read()

# %%
contents
# Out:
# 'Hello this is a text file\nthis is the second line\nthis is the third line\n'

# %% [markdown]
# Reading, Writing, Appending Modes
# *   Mode = 'r' is read only
# *   Mode = 'w' is write only (will overwrite files or create new!)
# *   Mode = 'a' is append only (will add on to files)
# *   Mode = 'r+' is reading and writing
# *   Mode = 'w+' is writing and reading (Overwrites existing files or creates a new file!)

# %%
# %%writefile my_new_file.txt
# ONE ON FIRST
# TWO ON SECOND
# THREE ON THIRD
# Out:
# Overwriting my_new_file.txt

# %%
with open('my_new_file.txt',mode='r') as f:
  print(f.read())
# Out:
# ONE ON FIRST
# TWO ON SECOND
# THREE ON THIRD

# %% [markdown]
# To add a new line

# %%
with open('my_new_file.txt',mode='a') as f:
  f.write('FOUR ON FOURTH')

# %%
with open('my_new_file.txt',mode='r') as f:
  print(f.read())
# Out:
# ONE ON FIRST
# TWO ON SECOND
# THREE ON THIRD
# FOUR ON FOURTH

# %% [markdown]
# 'w' for Writing

# %%
with open('dhfjdkshfjdks.txt',mode='w') as f:
  f.write('I CREATED THIS FILE!')

# %%
with open('dhfjdkshfjdks.txt',mode='r') as f:
  print(f.read())
# Out:
# I CREATED THIS FILE!
