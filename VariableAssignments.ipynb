# %%
a = 5

# %%
a
# Out:
# 5

# %%
a = 10

# %%
a
# Out:
# 10

# %%
a + a
# Out:
# 20

# %% [markdown]
# Can do reassignments with a reference to the same object

# %%
a
# Out:
# 10

# %% [markdown]
# If you keep running a = a + a, then run the a cell below it, then the output will result

# %%
a = a + a

# %%
a
# Out:
# 320

# %% [markdown]
# If we do not know what type a is

# %%
type(a)
# Out:
# int

# %% [markdown]
# Reassigning a to be a floating point number

# %%
a = 30.1

# %%
type(a)
# Out:
# float

# %% [markdown]
# Avoid using built in python keywords as variable names.
# Click "kernel" > "Restart kernel" to fix mistakes. Run the relevant cells above that you want to define.

# %%
int = 4

# %%
my_income = 100

tax_rate = 0.1

my_taxes = my_income * tax_rate

# %%
my_taxes
# Out:
# 10.0
