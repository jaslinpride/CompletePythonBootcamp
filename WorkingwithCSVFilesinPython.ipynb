# %% [markdown]
# Click on “15-PDFs-and-Spreadsheets”. Open and Save your Notebook in the same folder.
#
# Type “pwd” in cell to check your Notebook location

# %%
pwd
# Out:
# '/content'

# %% [markdown]
# Common Coding Error

# %%
import csv

# %%
# Open the File
data = open('example.csv',encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_29172/1171330621.py in <cell line: 0>()
#       1 # Open the File
# ----> 2 data = open('example.csv',encoding='utf-8')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'example.csv'

# %%
# Call CSV.Reader on the File (Convert it into CSV Data)
csv_data = csv.reader(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_29172/3714311106.py in <cell line: 0>()
#       1 # Call CSV.Reader on the File (Convert it into CSV Data)
# ----> 2 csv_data = csv.reader(data)
#
# NameError: name 'data' is not defined

# %%
data_lines = list(csv_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_29172/4240225183.py in <cell line: 0>()
# ----> 1 data_lines = list(csv_data)
#
# NameError: name 'csv_data' is not defined

# %%
data_lines
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_29172/2925119903.py in <cell line: 0>()
# ----> 1 data_lines
#
# NameError: name 'data_lines' is not defined

# %% [markdown]
# To know the Column Names

# %%
data_lines[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_29172/4047524639.py in <cell line: 0>()
# ----> 1 data_lines[0]
#
# NameError: name 'data_lines' is not defined

# %% [markdown]
# To know How Many Rows of Data there are

# %%
len(data_lines)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_29172/1737888501.py in <cell line: 0>()
# ----> 1 len(data_lines)
#
# NameError: name 'data_lines' is not defined

# %%
for line in data_lines[:5]:
  print(line)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_29172/1873993082.py in <cell line: 0>()
# ----> 1 for line in data_lines[:5]:
#       2   print(line)
#
# NameError: name 'data_lines' is not defined

# %% [markdown]
# Can Now Extract Any Row you Want (Row 10)

# %%
data_lines[10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_29172/3653548827.py in <cell line: 0>()
# ----> 1 data_lines[10]
#
# NameError: name 'data_lines' is not defined

# %% [markdown]
# Extracting a Single Value

# %%
data_lines[10][3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_29172/1691937176.py in <cell line: 0>()
# ----> 1 data_lines[10][3]
#
# NameError: name 'data_lines' is not defined

# %% [markdown]
# All E-Mails in Every Single Row

# %%
all_emails = []

# %%
for line in data_lines[1:15]:
  all_emails.append(line[3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_29172/2898206694.py in <cell line: 0>()
# ----> 1 for line in data_lines[1:15]:
#       2   all_emails.append(line[3])
#
# NameError: name 'data_lines' is not defined

# %%
all_emails
# Out:
# []

# %%
for line in data_lines[1:]:
  all_emails.append(line[3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_29172/1309041967.py in <cell line: 0>()
# ----> 1 for line in data_lines[1:]:
#       2   all_emails.append(line[3])
#
# NameError: name 'data_lines' is not defined

# %%
all_emails
# Out:
# []

# %% [markdown]
# A List of Full Names

# %%
full_names = []

# %%
for line in data_lines[1:]:
  full_names.append(line[1]+' '+line[2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_29172/934202176.py in <cell line: 0>()
# ----> 1 for line in data_lines[1:]:
#       2   full_names.append(line[1]+' '+line[2])
#
# NameError: name 'data_lines' is not defined

# %%
full_names
# Out:
# []

# %% [markdown]
# How to Write to a CSV File

# %%
file_to_output = open('to_save_file.csv',mode='w',newline='')

# %%
csv_writer = csv.writer(file_to_output,delimiter=',')

# %% [markdown]
# Write Row

# %%
csv_writer.writerow(['a','b','c'])
# Out:
# 7

# %% [markdown]
# Write Multiple Rows

# %%
csv_writer.writerows([['1','2','3'],['4','5','6']])

# %% [markdown]
# Close the File

# %%
file_to_output.close()

# %% [markdown]
# Add New Rows

# %%
f = open('to_save_file.csv',mode='a',newline='')

# %%
csv_writer = csv.writer(f)

# %%
csv_writer.writerow(['1','2','3'])
# Out:
# 7
