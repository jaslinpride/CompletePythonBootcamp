# %%
s = 'hello world'

# %% [markdown]
# Capitalize Method

# %%
s.capitalize()
# Out:
# 'Hello world'

# %% [markdown]
# Upper Method

# %%
s.upper()
# Out:
# 'HELLO WORLD'

# %% [markdown]
# Lower Method

# %%
s.lower()
# Out:
# 'hello world'

# %% [markdown]
# Location Method

# %%
s.find('o')
# Out:
# 4

# %% [markdown]
# Counting Method

# %%
s.count('o')
# Out:
# 2

# %% [markdown]
# Formatting Methods

# %% [markdown]
# Center Method

# %%
s
# Out:
# 'hello world'

# %%
s.center(20,'z')
# Out:
# 'zzzzhello worldzzzzz'

# %% [markdown]
# Expand Tabs Method

# %%
'hello/thi'
# Out:
# 'hello/thi'

# %%
print('hello/thi')
# Out:
# hello/thi

# %%
'hello/thi'.expandtabs()
# Out:
# 'hello/thi'

# %%
s = 'hello'

# %% [markdown]
# Isalnum

# %%
s.isalnum()
# Out:
# True

# %% [markdown]
# Isalpha

# %%
s.isalpha()
# Out:
# True

# %% [markdown]
# Islower

# %%
s.islower()
# Out:
# True

# %% [markdown]
# Isspace

# %%
s.isspace()
# Out:
# False

# %% [markdown]
# istitle

# %%
s.istitle()
# Out:
# False

# %% [markdown]
# Upper

# %%
s.isupper()
# Out:
# False

# %%
'HELLO'.isupper()
# Out:
# True

# %% [markdown]
# endswith Method

# %%
s.endswith('o')
# Out:
# True

# %%
s[-1] == 'o'
# Out:
# True

# %% [markdown]
# Regular Expression Operations

# %% [markdown]
# Split

# %%
s.split('e')
# Out:
# ['h', 'llo']

# %%
s = 'hiihhihihihhhi'

# %%
s.split('i')
# Out:
# ['h', '', 'hh', 'h', 'h', 'hhh', '']

# %% [markdown]
# Partition

# %%
s.partition('i')
# Out:
# ('h', 'i', 'ihhihihihhhi')
