# %% [markdown]
# Import PyPDF2 after Installing

# %%
import PyPDF2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_3788/314715566.py in <cell line: 0>()
# ----> 1 import PyPDF2
#
# ModuleNotFoundError: No module named 'PyPDF2'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# Open the PDF and Attach a Reader Object

# %%
f = open('Working_Business_Proposal.pdf','rb')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3788/820057086.py in <cell line: 0>()
# ----> 1 f = open('Working_Business_Proposal.pdf','rb')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Working_Business_Proposal.pdf'

# %% [markdown]
# To Ensure you can Work with the File

# %%
pdf_reader = PyPDF2.PdfFileReader(f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3788/1497031239.py in <cell line: 0>()
# ----> 1 pdf_reader = PyPDF2.PdfFileReader(f)
#
# NameError: name 'PyPDF2' is not defined

# %% [markdown]
# View Number of Pages in PDF

# %%
pdf_reader.numPages
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3788/3200850659.py in <cell line: 0>()
# ----> 1 pdf_reader.numPages
#
# NameError: name 'pdf_reader' is not defined

# %% [markdown]
# Grabbing the First Page

# %%
page_one = pdf_reader.getPage(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3788/2132211282.py in <cell line: 0>()
# ----> 1 page_one = pdf_reader.getPage(0)
#
# NameError: name 'pdf_reader' is not defined

# %% [markdown]
# Get Text from First Page

# %%
page_one_text = page_one.extractText()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3788/3562241691.py in <cell line: 0>()
# ----> 1 page_one_text = page_one.extractText()
#
# NameError: name 'page_one' is not defined

# %%
page_one_text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3788/1545938932.py in <cell line: 0>()
# ----> 1 page_one_text
#
# NameError: name 'page_one_text' is not defined

# %% [markdown]
# Close Off

# %%
f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3788/4000743260.py in <cell line: 0>()
# ----> 1 f.close()
#
# NameError: name 'f' is not defined

# %% [markdown]
# Adding to PDF Files

# %%
f = open('Working_Business_Proposal.pdf','rb')
pdf_reader = PyPDF2.PdfFileReader(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3788/2829803918.py in <cell line: 0>()
# ----> 1 f = open('Working_Business_Proposal.pdf','rb')
#       2 pdf_reader = PyPDF2.PdfFileReader(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Working_Business_Proposal.pdf'

# %%
first_page = pdf_reader.getPage(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3788/267212340.py in <cell line: 0>()
# ----> 1 first_page = pdf_reader.getPage(0)
#
# NameError: name 'pdf_reader' is not defined

# %% [markdown]
# Programmatically Grab All First Pages from PDF

# %%
pdf_writer = PyPDF2.PdfFileWriter()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3788/1447960235.py in <cell line: 0>()
# ----> 1 pdf_writer = PyPDF2.PdfFileWriter()
#
# NameError: name 'PyPDF2' is not defined

# %%
type(first_page)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3788/1568554832.py in <cell line: 0>()
# ----> 1 type(first_page)
#
# NameError: name 'first_page' is not defined

# %%
pdf_writer.addPage(first_page)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3788/1551252852.py in <cell line: 0>()
# ----> 1 pdf_writer.addPage(first_page)
#
# NameError: name 'pdf_writer' is not defined

# %% [markdown]
# Open a New File and Write to It

# %%
pdf_output = open('Some_BrandNew_Doc.pdf','wb')

# %%
pdf_writer.write(pdf_output)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3788/13868420.py in <cell line: 0>()
# ----> 1 pdf_writer.write(pdf_output)
#
# NameError: name 'pdf_writer' is not defined

# %%
f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3788/4000743260.py in <cell line: 0>()
# ----> 1 f.close()
#
# NameError: name 'f' is not defined

# %% [markdown]
# Grabbing All the Text in a PDF File

# %%
f = open('Working_Business_Proposal.pdf','rb')

pdf_text = []

pdf_reader = PyPDF2.PdfFileReader(f)

for num in range(pdf_reader.numPages):

  page = pdf_reader.getPage(num)

  pdf_text.append(page.extractText())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3788/4212370311.py in <cell line: 0>()
# ----> 1 f = open('Working_Business_Proposal.pdf','rb')
#       2
#       3 pdf_text = []
#       4
#       5 pdf_reader = PyPDF2.PdfFileReader(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Working_Business_Proposal.pdf'

# %%
pdf_text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3788/3491337222.py in <cell line: 0>()
# ----> 1 pdf_text
#
# NameError: name 'pdf_text' is not defined

# %% [markdown]
# Text on First Page

# %%
pdf_text[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3788/3136539480.py in <cell line: 0>()
# ----> 1 pdf_text[0]
#
# NameError: name 'pdf_text' is not defined

# %% [markdown]
# Text on Second Page

# %%
pdf_text[1]

# %% [markdown]
# Printing out the String shows where the new lines stand

# %%
print(pdf_text)
