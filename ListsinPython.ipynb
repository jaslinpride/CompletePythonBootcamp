# %%
my_list = [1,2,3]

# %%
my_list = ['STRING',100,23.2]

# %%
len(my_list)
# Out:
# 3

# %% [markdown]
# Because a list is an ordered sequence of elements, we can use indexing and slicing.

# %%
mylist = ['one','two','three']

# %%
mylist[0]
# Out:
# 'one'

# %%
mylist[1:]
# Out:
# ['two', 'three']

# %% [markdown]
# You can also concatenate lists together

# %%
another_list = ['four','five']

# %%
mylist + another_list
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %% [markdown]
# You are not saving the result so if you call back mylist or another_list you still have the two seperate lists.

# %%
mylist
# Out:
# ['one', 'two', 'three']

# %%
another_list
# Out:
# ['four', 'five']

# %% [markdown]
# you would have to change the initial lists

# %%
new_list = mylist + another_list

# %%
new_list
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %% [markdown]
# You can mutate or change around the list

# %%
new_list
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
new_list[0] = 'ONE ALL CAPS'

# %%
new_list
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five']

# %% [markdown]
# Adding a new item to the end of a list

# %%
new_list.append('six')

# %%
new_list
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five', 'six']

# %%
new_list.append('seven')

# %%
new_list
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five', 'six', 'seven']

# %% [markdown]
# Removing an item from the end of a list

# %%
new_list.pop()
# Out:
# 'seven'

# %%
new_list
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five', 'six']

# %% [markdown]
# Saving a popped item

# %%
popped_item = new_list.pop()

# %%
popped_item
# Out:
# 'six'

# %%
new_list
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five']

# %% [markdown]
# Removing an item at a specific index

# %%
new_list.pop(0)
# Out:
# 'ONE ALL CAPS'

# %%
new_list
# Out:
# ['two', 'three', 'four', 'five']

# %% [markdown]
# Sort and Reverse

# %%
new_list = ['a','e','x','b','c']
num_list = [4,1,8,3]

# %%
new_list.sort()

# %%
new_list
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %% [markdown]
# None Type: type for a none object

# %%
my_sorted_list = new_list.sort()

# %%
type(my_sorted_list)
# Out:
# NoneType

# %% [markdown]
# Correct Way

# %%
new_list.sort()
my_sorted_list = new_list

# %%
my_sorted_list
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %% [markdown]
# Sorting the num_list

# %%
num_list
# Out:
# [4, 1, 8, 3]

# %%
num_list.sort()

# %%
num_list
# Out:
# [1, 3, 4, 8]

# %% [markdown]
# Reverse method off a list

# %%
num_list.reverse()

# %%
num_list
# Out:
# [8, 4, 3, 1]
