# %%
l = [1,2,3]

# %% [markdown]
# Append Method

# %%
l = [1,2,3]

# %%
l.append(4)

# %%
l
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# Count Method

# %%
l.count(10)
# Out:
# 0

# %%
l.count(1)
# Out:
# 1

# %% [markdown]
# Extend Method

# %%
x = [1,2,3]
x.append([4,5])
print(x)
# Out:
# [1, 2, 3, [4, 5]]

# %%
x = [1,2,3]
x.extend([4,5])
print(x)
# Out:
# [1, 2, 3, 4, 5]

# %%
l
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# Index Method

# %%
l.index(2)
# Out:
# 1

# %% [markdown]
# You will get an error if you try to index something that is not in your list.

# %%
l.index(10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_7467/3665343044.py in <cell line: 0>()
# ----> 1 l.index(10)
#
# ValueError: 10 is not in list

# %% [markdown]
# Insert Method

# %%
l.insert(2,'inserted')

# %%
l
# Out:
# [1, 2, 'inserted', 3, 4]

# %% [markdown]
# Pop Method

# %%
ele = l.pop()

# %%
ele
# Out:
# 4

# %%
l
# Out:
# [1, 2, 'inserted', 3]

# %% [markdown]
# You can pass an index into pop

# %%
l.pop(0)
# Out:
# 1

# %%
l
# Out:
# [2, 'inserted', 3]

# %% [markdown]
# Remove Method

# %%
l.remove('inserted')

# %%
l
# Out:
# [2, 3]

# %% [markdown]
# Only removes the first instance

# %%
l = [1,2,3,4,3]

# %%
l.remove(3)

# %%
l
# Out:
# [1, 2, 4, 3]

# %% [markdown]
# Reverse Method

# %%
l.reverse()

# %%
l
# Out:
# [3, 4, 2, 1]

# %% [markdown]
# Sort Method

# %%
l.sort()

# %%
l
# Out:
# [1, 2, 3, 4]
